# %%
import sys
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

import time

import tensorflow as tf
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.layers import Conv1D, ZeroPadding1D
from keras.models import Model
from keras.backend import clear_session

from keras.layers.normalization import BatchNormalization
from keras.layers.pooling import MaxPooling2D
from keras.layers.pooling import MaxPooling1D
from keras.layers.merge import Concatenate
from keras.layers.core import Lambda, Flatten, Dense
from keras.initializers import glorot_uniform, RandomNormal
from keras.utils.vis_utils import plot_model

from keras.engine.topology import Layer
from keras.regularizers import l2
from keras import backend as K

from sklearn.utils import shuffle

import random as rd

# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ddou/.local/lib/python3.6/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Using TensorFlow backend.

# %% [markdown]
# ### Please give below paths as per the paths in your system

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 10176627707656312383
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 9786291394594774706
# physical_device_desc: "device: XLA_CPU device"
# ]

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  0

# %%
K.tensorflow_backend._get_available_gpus()
# Out:
# []

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.14.0'

# %%
def read_data(path, num=40, mode='inter'):
    train_dict = {}
    test_dict = {}
    categories = []
    for filepath in os.listdir(path):
        category = filepath.split('.')[0].split('_')[0]
        info = filepath.split('.')[0].split('_')[1]      
        if info == mode:
            print('Reading from:', filepath)
            categories.append(category)
            
            d = np.loadtxt(path+filepath, delimiter=' ')
            d = d[np.random.choice(d.shape[0], num, replace=False)]
            
            train_num = int(num*0.5)
            indices = np.arange(num)
            train_indices = np.random.choice(indices, train_num, replace=False)
            test_indices = np.setdiff1d(indices, train_indices)

            train_dict[category] = d[train_indices].reshape(train_num,d.shape[1],1)
            test_dict[category] = d[test_indices].reshape(num-train_num,d.shape[1],1)
            print('training data size:', train_dict[category].shape)
            print('test data size:', test_dict[category].shape)
    
    return train_dict, test_dict, categories, d.shape[1]

# %%
path = 'http3/'
train_dict, test_dict, categories, data_length = read_data(path)
# Out:
# Reading from: y_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: gc_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: gd_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: gdr_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: tr_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: gf_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: tb_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)
# Reading from: g_inter.txt
# training data size: (20, 19, 1)
# test data size: (20, 19, 1)

# %%
train_dict.keys()
# Out:
# dict_keys(['y', 'gc', 'gd', 'gdr', 'tr', 'gf', 'tb', 'g'])

# %%
def initialize_weights(shape, dtype, name=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer weights with mean as 0.0 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.0, scale = 1e-2, size = shape)

def initialize_bias(shape, dtype, name=None):
    """
        The paper, http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
        suggests to initialize CNN layer bias with mean as 0.5 and standard deviation of 0.01
    """
    return np.random.normal(loc = 0.5, scale = 1e-2, size = shape)

# %%
def siamese_model(input_shape):
    """
        Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """
    
    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv1D(64, 5, activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling1D())
    model.add(Conv1D(128, 3, activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling1D())
#     model.add(Conv1D(128, 2, activation='relu', kernel_initializer=initialize_weights,
#                      bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
#     model.add(MaxPooling1D())
    model.add(Conv1D(256, 2, activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
def siamese_model_p(input_shape):
    """
        Model architecture based on the one provided in: http://www.cs.utoronto.ca/~gkoch/files/msc-thesis.pdf
    """
    
    # Define the tensors for the two input images
    left_input = Input(input_shape)
    right_input = Input(input_shape)
    
    # Convolutional Neural Network
    model = Sequential()
    model.add(Conv1D(64, 100, strides=10, activation='relu', input_shape=input_shape,
                   kernel_initializer=initialize_weights, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling1D())
    model.add(Conv1D(128, 50, strides=5, activation='relu',
                     kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(MaxPooling1D())
#     model.add(Conv1D(128, 2, activation='relu', kernel_initializer=initialize_weights,
#                      bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
#     model.add(MaxPooling1D())
    model.add(Conv1D(256, 10, strides=1, activation='relu', kernel_initializer=initialize_weights,
                     bias_initializer=initialize_bias, kernel_regularizer=l2(2e-4)))
    model.add(Flatten())
    model.add(Dense(4096, activation='sigmoid',
                   kernel_regularizer=l2(1e-3),
                   kernel_initializer=initialize_weights,bias_initializer=initialize_bias))
    
    # Generate the encodings (feature vectors) for the two images
    encoded_l = model(left_input)
    encoded_r = model(right_input)
    
    # Add a customized layer to compute the absolute difference between the encodings
    L1_layer = Lambda(lambda tensors:K.abs(tensors[0] - tensors[1]))
    L1_distance = L1_layer([encoded_l, encoded_r])
    
    # Add a dense layer with a sigmoid unit to generate the similarity score
    prediction = Dense(1,activation='sigmoid',bias_initializer=initialize_bias)(L1_distance)
    
    # Connect the inputs with the outputs
    siamese_net = Model(inputs=[left_input,right_input],outputs=prediction)
    
    # return the model
    return siamese_net

# %%
clear_session()
model = siamese_model((data_length, 1))
# model = siamese_model_p((data_length, 1))
model.summary()
# Out:
# WARNING:tensorflow:From /home/ddou/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 19, 1)        0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 19, 1)        0
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 4096)         1143552     input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 4096)         0           sequential_1[1][0]
#                                                                  sequential_1[2][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            4097        lambda_1[0][0]
# ==================================================================================================
# Total params: 1,147,649
# Trainable params: 1,147,649
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
optimizer = Adam(6e-5)
model.compile(loss="binary_crossentropy", optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /home/ddou/.local/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:180: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
def get_batch_1(dict_, categories, batch_size):
    
    categories_batch = np.random.choice(categories, batch_size)
#     print(categories_batch)
    
#     First half use same class
    division_point = int(batch_size / 2)
    
    batch_1 = np.zeros((batch_size, data_length, 1))
    batch_2 = np.zeros((batch_size, data_length, 1))

    label = np.zeros((batch_size,))
    
    for i in range(batch_size):
        data_temp = dict_[categories_batch[i]]
        if i <= division_point:
            data_batch = data_temp[np.random.choice(data_temp.shape[0], 2, replace=True)]
            batch_1[i,:,:] = data_batch[0].reshape(data_length,1)
            batch_2[i,:,:] = data_batch[1].reshape(data_length,1)
            label[i] = 1
        else:
            categories_temp = categories.copy()
            categories_temp.remove(categories_batch[i])
            batch_1[i,:,:] = data_temp[rd.randint(0, len(data_temp) - 1)]
            data_temp_2 = dict_[rd.sample(categories_temp, 1)[0]]
            batch_2[i,:,:] = data_temp_2[np.random.choice(data_temp_2.shape[0], 1, replace=True)]
            
#     print(batch_1.shape, batch_2.shape)
    batch_1, batch_2, label = shuffle(batch_1, batch_2, label)
    return batch_1, batch_2, label

# %%
test_class_index = 0

def get_batch_test(dict_, categories, N, test_class_sequential = False):
    
    global test_class_index
#     print(categories)
    categories_batch = rd.sample(categories, N)
#     print(categories_batch)
    
    if test_class_sequential == True:
        #print("<==========Sequential Test==========>")
        categories_temp = categories.copy()
        categories_temp.remove(categories[test_class_index])
        categories_batch[0] = categories[test_class_index]
        categories_batch[1:] = rd.sample(categories_temp, N - 1)
#         print(categories_batch)
        if test_class_index == int(len(categories) - 1):
            test_class_index = 0
            #print("<==========Sequential Test END==========>")
        else:
            test_class_index += 1
    
    test_data = dict_[categories_batch[0]]
    test_sample = test_data[np.random.choice(test_data.shape[0], 2, replace=True)]
    
    test_sample_copies = np.zeros((N, data_length, 1))
    support_set = np.zeros((N, data_length, 1))
    
    test_sample_copies[0,:,:] = test_sample[0]
    support_set[0,:,:] = test_sample[1]
    
    label = np.zeros((N,))
    label[0,] = 1
    
    for i in range(1, N):
#         print(i, len(dict_[categories_batch[i]]))
        support_data = dict_[categories_batch[i]]
        support_set[i,:,:] = support_data[np.random.choice(support_data.shape[0], 1, replace=True)]
        test_sample_copies[i,:,:] = test_sample[0].copy()
            
#     print(test_image.shape, support_set.shape)
    test_image_copies, support_set, label = shuffle(test_sample_copies, support_set, label)
    return test_image_copies, support_set, label

# %%
def test(model, dict_, categories, N, test_num, test_class_sequential = False):
    correct_num = 0
    print("Use " + str(N) + " way one-shot learning on " + str(test_num) + " test sets.")
    
    for i in range(test_num):
        test_image_copies, support_set, label = get_batch_test(dict_, categories, N, test_class_sequential)
        probs = model.predict([test_image_copies, support_set])
#         print(probs)
        if np.argmax(probs) == np.argmax(label):
        
#             print("Bingo!!!")
            correct_num += 1
#         else:
#             print("Ah-oh...")
    accuracy = 1.0 * correct_num / test_num
    print("Accuracy is " + str(accuracy))
    return accuracy

# %%
# Hyper parameters
evaluate_every = 10 # interval for evaluating on one-shot tasks
batch_size = 16
n_iter = 2000 # No. of training iterations
N_way = 8 # how many classes for testing one-shot tasks
n_val = 200 # how many one-shot tasks to validate on
best = -1

# %%
print("Starting training process!")
print("-------------------------------------")
t_start = time.time()
train_result = {
    'iter_num':[],
    'accuracy':[],
    'loss':[]
}

# model.reset_states()

for i in range(1, n_iter+1):
    batch_1, batch_2, label = get_batch_1(train_dict, categories, batch_size)
    loss = model.train_on_batch([batch_1, batch_2], label)
    if i % evaluate_every == 0:
        print("\n ------------- \n")
        print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
        print("Train Loss: {0}".format(loss)) 
        val_acc = test(model, test_dict, categories, N_way, n_val)
        #model.save_weights(os.path.join(model_path, 'weights.{}.h5'.format(i)))
        print("Current best: {0}, previous best: {1}".format(val_acc, best))
#         accurracy.append((i, val_acc))
        train_result['iter_num'].append(i)
        train_result['accuracy'].append(val_acc)
        train_result['loss'].append(loss)
        if val_acc >= best:
            best = val_acc
            
# from keras.models import load_model
# model.save('siamese_'+str(best)+'.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Starting training process!
# -------------------------------------
# WARNING:tensorflow:From /home/ddou/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
#
#  -------------
#
# Time for 10 iterations: 0.013698418935139975 mins
# Train Loss: 0.7738513350486755
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.3
# Current best: 0.3, previous best: -1
#
#  -------------
#
# Time for 20 iterations: 0.01982478698094686 mins
# Train Loss: 0.5678308010101318
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.32
# Current best: 0.32, previous best: 0.3
#
#  -------------
#
# Time for 30 iterations: 0.025447213649749757 mins
# Train Loss: 0.6386256814002991
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.32
#
#  -------------
#
# Time for 40 iterations: 0.030771756172180177 mins
# Train Loss: 0.6728739142417908
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.37
#
#  -------------
#
# Time for 50 iterations: 0.03615802526473999 mins
# Train Loss: 0.673040509223938
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.295
# Current best: 0.295, previous best: 0.37
#
#  -------------
#
# Time for 60 iterations: 0.041484586397806805 mins
# Train Loss: 0.6235684752464294
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.37
#
#  -------------
#
# Time for 70 iterations: 0.04677114486694336 mins
# Train Loss: 0.4108349680900574
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.32
# Current best: 0.32, previous best: 0.37
#
#  -------------
#
# Time for 80 iterations: 0.05212319294611613 mins
# Train Loss: 0.534973680973053
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.255
# Current best: 0.255, previous best: 0.37
#
#  -------------
#
# Time for 90 iterations: 0.057443201541900635 mins
# Train Loss: 0.4949721395969391
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.395
# Current best: 0.395, previous best: 0.37
#
#  -------------
#
# Time for 100 iterations: 0.06275790135065715 mins
# Train Loss: 0.45340800285339355
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.295
# Current best: 0.295, previous best: 0.395
#
#  -------------
#
# Time for 110 iterations: 0.06832619110743204 mins
# Train Loss: 0.6267479658126831
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.285
# Current best: 0.285, previous best: 0.395
#
#  -------------
#
# Time for 120 iterations: 0.07392061948776245 mins
# Train Loss: 0.5519471168518066
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.395
#
#  -------------
#
# Time for 130 iterations: 0.07932858467102051 mins
# Train Loss: 0.34998011589050293
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.395
# Current best: 0.395, previous best: 0.395
#
#  -------------
#
# Time for 140 iterations: 0.08469932874043783 mins
# Train Loss: 0.48912400007247925
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.395
#
#  -------------
#
# Time for 150 iterations: 0.09008630116780598 mins
# Train Loss: 0.3603407144546509
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.395
#
#  -------------
#
# Time for 160 iterations: 0.0955652634302775 mins
# Train Loss: 0.6084956526756287
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.395
#
#  -------------
#
# Time for 170 iterations: 0.10101139942804972 mins
# Train Loss: 0.550632119178772
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.395
#
#  -------------
#
# Time for 180 iterations: 0.10706584453582764 mins
# Train Loss: 0.4080526828765869
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.395
#
#  -------------
#
# Time for 190 iterations: 0.11310756206512451 mins
# Train Loss: 0.4375203847885132
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.395
#
#  -------------
#
# Time for 200 iterations: 0.11898314952850342 mins
# Train Loss: 0.44478797912597656
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.42
# Current best: 0.42, previous best: 0.395
#
#  -------------
#
# Time for 210 iterations: 0.12446101903915405 mins
# Train Loss: 0.4316578507423401
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.285
# Current best: 0.285, previous best: 0.42
#
#  -------------
#
# Time for 220 iterations: 0.12990891933441162 mins
# Train Loss: 0.27690771222114563
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.42
#
#  -------------
#
# Time for 230 iterations: 0.13607437610626222 mins
# Train Loss: 0.33742961287498474
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.42
#
#  -------------
#
# Time for 240 iterations: 0.14169546365737914 mins
# Train Loss: 0.7104422450065613
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.42
#
#  -------------
#
# Time for 250 iterations: 0.14702149629592895 mins
# Train Loss: 0.4178500473499298
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.38
# Current best: 0.38, previous best: 0.42
#
#  -------------
#
# Time for 260 iterations: 0.1524191657702128 mins
# Train Loss: 0.322510302066803
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.32
# Current best: 0.32, previous best: 0.42
#
#  -------------
#
# Time for 270 iterations: 0.15792393287022907 mins
# Train Loss: 0.43532708287239075
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.42
#
#  -------------
#
# Time for 280 iterations: 0.16398246288299562 mins
# Train Loss: 0.5162521004676819
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.42
#
#  -------------
#
# Time for 290 iterations: 0.1700661579767863 mins
# Train Loss: 0.3272002041339874
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.42
#
#  -------------
#
# Time for 300 iterations: 0.17543040911356608 mins
# Train Loss: 0.2995559573173523
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.28
# Current best: 0.28, previous best: 0.42
#
#  -------------
#
# Time for 310 iterations: 0.18106704552968342 mins
# Train Loss: 0.5366794466972351
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.405
# Current best: 0.405, previous best: 0.42
#
#  -------------
#
# Time for 320 iterations: 0.18683311541875203 mins
# Train Loss: 0.693071722984314
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.31
# Current best: 0.31, previous best: 0.42
#
#  -------------
#
# Time for 330 iterations: 0.192514967918396 mins
# Train Loss: 0.7345954179763794
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.42
#
#  -------------
#
# Time for 340 iterations: 0.1980084260304769 mins
# Train Loss: 0.4829312264919281
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.42
#
#  -------------
#
# Time for 350 iterations: 0.20376913547515868 mins
# Train Loss: 0.5356703996658325
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.42
#
#  -------------
#
# Time for 360 iterations: 0.20910887718200682 mins
# Train Loss: 0.37990057468414307
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.295
# Current best: 0.295, previous best: 0.42
#
#  -------------
#
# Time for 370 iterations: 0.21503012577692668 mins
# Train Loss: 0.4261431396007538
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.31
# Current best: 0.31, previous best: 0.42
#
#  -------------
#
# Time for 380 iterations: 0.22086780071258544 mins
# Train Loss: 0.47193577885627747
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.43
# Current best: 0.43, previous best: 0.42
#
#  -------------
#
# Time for 390 iterations: 0.2272325873374939 mins
# Train Loss: 0.5359071493148804
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.43
#
#  -------------
#
# Time for 400 iterations: 0.23305936654408774 mins
# Train Loss: 0.4710134267807007
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.44
# Current best: 0.44, previous best: 0.43
#
#  -------------
#
# Time for 410 iterations: 0.2385833144187927 mins
# Train Loss: 0.4802595376968384
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.285
# Current best: 0.285, previous best: 0.44
#
#  -------------
#
# Time for 420 iterations: 0.24437585671742756 mins
# Train Loss: 0.24462692439556122
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 430 iterations: 0.2500524163246155 mins
# Train Loss: 0.5298629403114319
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 440 iterations: 0.25579601923624673 mins
# Train Loss: 0.4569045603275299
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.38
# Current best: 0.38, previous best: 0.44
#
#  -------------
#
# Time for 450 iterations: 0.2614358186721802 mins
# Train Loss: 0.5853057503700256
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.44
#
#  -------------
#
# Time for 460 iterations: 0.2669230461120605 mins
# Train Loss: 0.42241960763931274
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 470 iterations: 0.27240332365036013 mins
# Train Loss: 0.38842663168907166
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.44
#
#  -------------
#
# Time for 480 iterations: 0.2778817852338155 mins
# Train Loss: 0.5939711332321167
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 490 iterations: 0.2835143407185872 mins
# Train Loss: 0.5529910922050476
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.31
# Current best: 0.31, previous best: 0.44
#
#  -------------
#
# Time for 500 iterations: 0.2890773018201192 mins
# Train Loss: 0.432575523853302
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.44
#
#  -------------
#
# Time for 510 iterations: 0.294419793287913 mins
# Train Loss: 0.5475826263427734
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 520 iterations: 0.2999532461166382 mins
# Train Loss: 0.31735438108444214
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.405
# Current best: 0.405, previous best: 0.44
#
#  -------------
#
# Time for 530 iterations: 0.30540400743484497 mins
# Train Loss: 0.34248828887939453
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 540 iterations: 0.3111709117889404 mins
# Train Loss: 0.41603878140449524
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 550 iterations: 0.3172752300898234 mins
# Train Loss: 0.6149193644523621
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 560 iterations: 0.3227333505948385 mins
# Train Loss: 0.40943068265914917
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 570 iterations: 0.328218678633372 mins
# Train Loss: 0.5242308378219604
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 580 iterations: 0.3336936553319295 mins
# Train Loss: 0.5790627002716064
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 590 iterations: 0.33924768765767416 mins
# Train Loss: 0.39786088466644287
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 600 iterations: 0.344664478302002 mins
# Train Loss: 0.3743404150009155
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 610 iterations: 0.35019651254018147 mins
# Train Loss: 0.29524335265159607
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.275
# Current best: 0.275, previous best: 0.44
#
#  -------------
#
# Time for 620 iterations: 0.35574042797088623 mins
# Train Loss: 0.4572988748550415
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 630 iterations: 0.36116549571355183 mins
# Train Loss: 0.27976876497268677
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 640 iterations: 0.3666768113772074 mins
# Train Loss: 0.3105626404285431
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.44
#
#  -------------
#
# Time for 650 iterations: 0.37218748331069945 mins
# Train Loss: 0.4144728481769562
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.32
# Current best: 0.32, previous best: 0.44
#
#  -------------
#
# Time for 660 iterations: 0.37754472096761066 mins
# Train Loss: 0.4284246563911438
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 670 iterations: 0.3828700621922811 mins
# Train Loss: 0.5259112119674683
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 680 iterations: 0.38875972827275596 mins
# Train Loss: 0.5197200775146484
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 690 iterations: 0.3947078824043274 mins
# Train Loss: 0.5024533867835999
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.44
#
#  -------------
#
# Time for 700 iterations: 0.40024555921554567 mins
# Train Loss: 0.35633373260498047
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 710 iterations: 0.4056269645690918 mins
# Train Loss: 0.5902215242385864
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.3
# Current best: 0.3, previous best: 0.44
#
#  -------------
#
# Time for 720 iterations: 0.4111542741457621 mins
# Train Loss: 0.30805832147598267
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.29
# Current best: 0.29, previous best: 0.44
#
#  -------------
#
# Time for 730 iterations: 0.4165735642115275 mins
# Train Loss: 0.4243754744529724
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.44
#
#  -------------
#
# Time for 740 iterations: 0.42198002338409424 mins
# Train Loss: 0.22069041430950165
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.44
#
#  -------------
#
# Time for 750 iterations: 0.4273260513941447 mins
# Train Loss: 0.4770229458808899
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.425
# Current best: 0.425, previous best: 0.44
#
#  -------------
#
# Time for 760 iterations: 0.43259179989496865 mins
# Train Loss: 0.41727009415626526
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 770 iterations: 0.43804654677708943 mins
# Train Loss: 0.42102378606796265
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 780 iterations: 0.4438875476519267 mins
# Train Loss: 0.5635699033737183
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.44
#
#  -------------
#
# Time for 790 iterations: 0.44947062333424886 mins
# Train Loss: 0.43575456738471985
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.44
#
#  -------------
#
# Time for 800 iterations: 0.4549862504005432 mins
# Train Loss: 0.3078015446662903
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 810 iterations: 0.46078760623931886 mins
# Train Loss: 0.47449883818626404
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 820 iterations: 0.4662943204243978 mins
# Train Loss: 0.30703940987586975
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.44
#
#  -------------
#
# Time for 830 iterations: 0.47170725266138713 mins
# Train Loss: 0.7166854739189148
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.44
#
#  -------------
#
# Time for 840 iterations: 0.47704376379648844 mins
# Train Loss: 0.35972079634666443
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 850 iterations: 0.48254595200220746 mins
# Train Loss: 0.8934884667396545
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.44
#
#  -------------
#
# Time for 860 iterations: 0.4880891919136047 mins
# Train Loss: 0.4909150004386902
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 870 iterations: 0.49358583291371666 mins
# Train Loss: 0.3865528702735901
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 880 iterations: 0.49898256063461305 mins
# Train Loss: 0.46290138363838196
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 890 iterations: 0.5046482841173808 mins
# Train Loss: 0.24083064496517181
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 900 iterations: 0.5105669577916463 mins
# Train Loss: 0.5813313126564026
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.44
#
#  -------------
#
# Time for 910 iterations: 0.5163713733355204 mins
# Train Loss: 0.24830935895442963
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.44
#
#  -------------
#
# Time for 920 iterations: 0.5218751986821493 mins
# Train Loss: 0.5726954936981201
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.44
#
#  -------------
#
# Time for 930 iterations: 0.5274398525555929 mins
# Train Loss: 0.5531073212623596
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.3
# Current best: 0.3, previous best: 0.44
#
#  -------------
#
# Time for 940 iterations: 0.5334562222162883 mins
# Train Loss: 0.49178585410118103
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.29
# Current best: 0.29, previous best: 0.44
#
#  -------------
#
# Time for 950 iterations: 0.5394460995992024 mins
# Train Loss: 0.33099520206451416
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.38
# Current best: 0.38, previous best: 0.44
#
#  -------------
#
# Time for 960 iterations: 0.5456873893737793 mins
# Train Loss: 0.32020390033721924
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.44
# Current best: 0.44, previous best: 0.44
#
#  -------------
#
# Time for 970 iterations: 0.5516247550646464 mins
# Train Loss: 0.5438980460166931
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 980 iterations: 0.5572911779085795 mins
# Train Loss: 0.3887014091014862
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.44
#
#  -------------
#
# Time for 990 iterations: 0.5626536925633748 mins
# Train Loss: 0.3492944836616516
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 1000 iterations: 0.5685487429300944 mins
# Train Loss: 0.29650962352752686
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.405
# Current best: 0.405, previous best: 0.44
#
#  -------------
#
# Time for 1010 iterations: 0.5747115294138591 mins
# Train Loss: 0.46283960342407227
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.41
# Current best: 0.41, previous best: 0.44
#
#  -------------
#
# Time for 1020 iterations: 0.5802889466285706 mins
# Train Loss: 0.43988096714019775
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 1030 iterations: 0.5857882181803385 mins
# Train Loss: 0.3469614088535309
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 1040 iterations: 0.5914890686670939 mins
# Train Loss: 0.25238606333732605
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.44
#
#  -------------
#
# Time for 1050 iterations: 0.5970899383227031 mins
# Train Loss: 0.5947582125663757
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.44
#
#  -------------
#
# Time for 1060 iterations: 0.6027420004208882 mins
# Train Loss: 0.40722963213920593
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 1070 iterations: 0.6087286233901977 mins
# Train Loss: 0.7029195427894592
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.41
# Current best: 0.41, previous best: 0.44
#
#  -------------
#
# Time for 1080 iterations: 0.6146122137705485 mins
# Train Loss: 0.40898627042770386
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.44
#
#  -------------
#
# Time for 1090 iterations: 0.6203931887944539 mins
# Train Loss: 0.4095916748046875
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.44
#
#  -------------
#
# Time for 1100 iterations: 0.6261836647987366 mins
# Train Loss: 0.31009599566459656
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.33
# Current best: 0.33, previous best: 0.44
#
#  -------------
#
# Time for 1110 iterations: 0.6316027681032816 mins
# Train Loss: 0.5991328358650208
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.38
# Current best: 0.38, previous best: 0.44
#
#  -------------
#
# Time for 1120 iterations: 0.6379239281018575 mins
# Train Loss: 0.3950485289096832
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.44
#
#  -------------
#
# Time for 1130 iterations: 0.6435662706693014 mins
# Train Loss: 0.49629056453704834
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 1140 iterations: 0.6492995103200276 mins
# Train Loss: 0.44955188035964966
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 1150 iterations: 0.6547841389973958 mins
# Train Loss: 0.5187419056892395
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 1160 iterations: 0.6604488571484883 mins
# Train Loss: 0.3397405445575714
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.29
# Current best: 0.29, previous best: 0.44
#
#  -------------
#
# Time for 1170 iterations: 0.6665479818979899 mins
# Train Loss: 0.47897660732269287
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.44
#
#  -------------
#
# Time for 1180 iterations: 0.6731997132301331 mins
# Train Loss: 0.4213285446166992
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.425
# Current best: 0.425, previous best: 0.44
#
#  -------------
#
# Time for 1190 iterations: 0.6793717265129089 mins
# Train Loss: 0.45137256383895874
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.31
# Current best: 0.31, previous best: 0.44
#
#  -------------
#
# Time for 1200 iterations: 0.6852781057357789 mins
# Train Loss: 0.4349467158317566
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.44
#
#  -------------
#
# Time for 1210 iterations: 0.691381033261617 mins
# Train Loss: 0.6381752490997314
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.39
# Current best: 0.39, previous best: 0.44
#
#  -------------
#
# Time for 1220 iterations: 0.6974480549494425 mins
# Train Loss: 0.3895772099494934
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.44
#
#  -------------
#
# Time for 1230 iterations: 0.7040241161982218 mins
# Train Loss: 0.42996853590011597
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.44
#
#  -------------
#
# Time for 1240 iterations: 0.7099001248677571 mins
# Train Loss: 0.3684958815574646
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.44
#
#  -------------
#
# Time for 1250 iterations: 0.716508416334788 mins
# Train Loss: 0.182610422372818
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.395
# Current best: 0.395, previous best: 0.44
#
#  -------------
#
# Time for 1260 iterations: 0.722904113928477 mins
# Train Loss: 0.5093711018562317
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 1270 iterations: 0.7296306173006694 mins
# Train Loss: 0.5282943844795227
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 1280 iterations: 0.7354479352633159 mins
# Train Loss: 0.4681985378265381
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 1290 iterations: 0.7411557197570801 mins
# Train Loss: 0.418854296207428
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.44
#
#  -------------
#
# Time for 1300 iterations: 0.7465182224909465 mins
# Train Loss: 0.5879014730453491
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.415
# Current best: 0.415, previous best: 0.44
#
#  -------------
#
# Time for 1310 iterations: 0.7524466355641682 mins
# Train Loss: 0.46530187129974365
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.44
#
#  -------------
#
# Time for 1320 iterations: 0.7579804301261902 mins
# Train Loss: 0.2777866721153259
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.315
# Current best: 0.315, previous best: 0.44
#
#  -------------
#
# Time for 1330 iterations: 0.7635545611381531 mins
# Train Loss: 0.45354339480400085
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.295
# Current best: 0.295, previous best: 0.44
#
#  -------------
#
# Time for 1340 iterations: 0.7689603726069133 mins
# Train Loss: 0.31148213148117065
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.44
#
#  -------------
#
# Time for 1350 iterations: 0.7744087378184 mins
# Train Loss: 0.3962423801422119
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.445
# Current best: 0.445, previous best: 0.44
#
#  -------------
#
# Time for 1360 iterations: 0.7799360712369283 mins
# Train Loss: 0.4872848689556122
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.295
# Current best: 0.295, previous best: 0.445
#
#  -------------
#
# Time for 1370 iterations: 0.7853322943051656 mins
# Train Loss: 0.42949455976486206
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.445
#
#  -------------
#
# Time for 1380 iterations: 0.7908889770507812 mins
# Train Loss: 0.49475976824760437
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1390 iterations: 0.7965043385823568 mins
# Train Loss: 0.3347128927707672
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.445
#
#  -------------
#
# Time for 1400 iterations: 0.8020900408426921 mins
# Train Loss: 0.22679096460342407
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.445
#
#  -------------
#
# Time for 1410 iterations: 0.8078733364741008 mins
# Train Loss: 0.29794618487358093
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.445
#
#  -------------
#
# Time for 1420 iterations: 0.8137360453605652 mins
# Train Loss: 0.28302663564682007
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1430 iterations: 0.819513734181722 mins
# Train Loss: 0.4617342948913574
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1440 iterations: 0.8251575469970703 mins
# Train Loss: 0.41211965680122375
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.335
# Current best: 0.335, previous best: 0.445
#
#  -------------
#
# Time for 1450 iterations: 0.8305541753768921 mins
# Train Loss: 0.43053939938545227
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.32
# Current best: 0.32, previous best: 0.445
#
#  -------------
#
# Time for 1460 iterations: 0.8359697779019674 mins
# Train Loss: 0.45155787467956543
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.445
#
#  -------------
#
# Time for 1470 iterations: 0.8411991278330485 mins
# Train Loss: 0.36376211047172546
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1480 iterations: 0.8467751582463582 mins
# Train Loss: 0.3350195586681366
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1490 iterations: 0.8521737972895305 mins
# Train Loss: 0.21779164671897888
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1500 iterations: 0.857515017191569 mins
# Train Loss: 0.3390466868877411
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.415
# Current best: 0.415, previous best: 0.445
#
#  -------------
#
# Time for 1510 iterations: 0.8628613392512003 mins
# Train Loss: 0.7599056363105774
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1520 iterations: 0.8682400186856588 mins
# Train Loss: 0.37331169843673706
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1530 iterations: 0.8737444321314494 mins
# Train Loss: 0.6296706199645996
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.28
# Current best: 0.28, previous best: 0.445
#
#  -------------
#
# Time for 1540 iterations: 0.8793168385823568 mins
# Train Loss: 0.5961796641349792
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.445
#
#  -------------
#
# Time for 1550 iterations: 0.8846479336420695 mins
# Train Loss: 0.44965770840644836
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.445
#
#  -------------
#
# Time for 1560 iterations: 0.8899704535802205 mins
# Train Loss: 0.277846097946167
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.445
#
#  -------------
#
# Time for 1570 iterations: 0.895416812102 mins
# Train Loss: 0.41254112124443054
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.445
#
#  -------------
#
# Time for 1580 iterations: 0.900705349445343 mins
# Train Loss: 0.4854288101196289
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.445
#
#  -------------
#
# Time for 1590 iterations: 0.9060298363367717 mins
# Train Loss: 0.5077141523361206
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.34
# Current best: 0.34, previous best: 0.445
#
#  -------------
#
# Time for 1600 iterations: 0.9113485058148701 mins
# Train Loss: 0.47059956192970276
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.305
# Current best: 0.305, previous best: 0.445
#
#  -------------
#
# Time for 1610 iterations: 0.91690092086792 mins
# Train Loss: 0.35022836923599243
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1620 iterations: 0.922280740737915 mins
# Train Loss: 0.3101707100868225
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.42
# Current best: 0.42, previous best: 0.445
#
#  -------------
#
# Time for 1630 iterations: 0.9277968525886535 mins
# Train Loss: 0.4456360638141632
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1640 iterations: 0.9333938757578532 mins
# Train Loss: 0.4880487322807312
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.445
#
#  -------------
#
# Time for 1650 iterations: 0.9387544711430867 mins
# Train Loss: 0.3228685259819031
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1660 iterations: 0.9444590926170349 mins
# Train Loss: 0.34035801887512207
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1670 iterations: 0.9502076903978983 mins
# Train Loss: 0.34030526876449585
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.445
#
#  -------------
#
# Time for 1680 iterations: 0.9559536616007487 mins
# Train Loss: 0.43985599279403687
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1690 iterations: 0.9615326126416525 mins
# Train Loss: 0.42930158972740173
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.425
# Current best: 0.425, previous best: 0.445
#
#  -------------
#
# Time for 1700 iterations: 0.9674229661623637 mins
# Train Loss: 0.2945901155471802
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.29
# Current best: 0.29, previous best: 0.445
#
#  -------------
#
# Time for 1710 iterations: 0.9730666200319926 mins
# Train Loss: 0.5508815050125122
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.37
# Current best: 0.37, previous best: 0.445
#
#  -------------
#
# Time for 1720 iterations: 0.9784323374430338 mins
# Train Loss: 0.5628944635391235
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.405
# Current best: 0.405, previous best: 0.445
#
#  -------------
#
# Time for 1730 iterations: 0.9842119932174682 mins
# Train Loss: 0.3604578673839569
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.445
#
#  -------------
#
# Time for 1740 iterations: 0.9897010167439778 mins
# Train Loss: 0.33722805976867676
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1750 iterations: 0.9952353914578755 mins
# Train Loss: 0.35663408041000366
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1760 iterations: 1.0008793950080872 mins
# Train Loss: 0.34895285964012146
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.42
# Current best: 0.42, previous best: 0.445
#
#  -------------
#
# Time for 1770 iterations: 1.0064452171325684 mins
# Train Loss: 0.38142967224121094
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.395
# Current best: 0.395, previous best: 0.445
#
#  -------------
#
# Time for 1780 iterations: 1.0119503140449524 mins
# Train Loss: 0.5351963043212891
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.445
#
#  -------------
#
# Time for 1790 iterations: 1.017296282450358 mins
# Train Loss: 0.3151426911354065
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.345
# Current best: 0.345, previous best: 0.445
#
#  -------------
#
# Time for 1800 iterations: 1.0226172844568888 mins
# Train Loss: 0.23591625690460205
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.355
# Current best: 0.355, previous best: 0.445
#
#  -------------
#
# Time for 1810 iterations: 1.0280389626820883 mins
# Train Loss: 0.46720173954963684
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.3
# Current best: 0.3, previous best: 0.445
#
#  -------------
#
# Time for 1820 iterations: 1.034581184387207 mins
# Train Loss: 0.3883585035800934
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1830 iterations: 1.0403316815694172 mins
# Train Loss: 0.3759418725967407
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.405
# Current best: 0.405, previous best: 0.445
#
#  -------------
#
# Time for 1840 iterations: 1.0459232330322266 mins
# Train Loss: 0.49103784561157227
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.445
#
#  -------------
#
# Time for 1850 iterations: 1.0513108054796854 mins
# Train Loss: 0.44451284408569336
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.445
#
#  -------------
#
# Time for 1860 iterations: 1.0571138858795166 mins
# Train Loss: 0.3873382806777954
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.445
#
#  -------------
#
# Time for 1870 iterations: 1.0632301648457845 mins
# Train Loss: 0.373855322599411
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.385
# Current best: 0.385, previous best: 0.445
#
#  -------------
#
# Time for 1880 iterations: 1.0685365915298461 mins
# Train Loss: 0.42322295904159546
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.28
# Current best: 0.28, previous best: 0.445
#
#  -------------
#
# Time for 1890 iterations: 1.0744799812634787 mins
# Train Loss: 0.6303388476371765
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.395
# Current best: 0.395, previous best: 0.445
#
#  -------------
#
# Time for 1900 iterations: 1.0801047285397847 mins
# Train Loss: 0.5614331960678101
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.41
# Current best: 0.41, previous best: 0.445
#
#  -------------
#
# Time for 1910 iterations: 1.0855268200238546 mins
# Train Loss: 0.21878500282764435
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.325
# Current best: 0.325, previous best: 0.445
#
#  -------------
#
# Time for 1920 iterations: 1.0909817894299825 mins
# Train Loss: 0.5021206736564636
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.31
# Current best: 0.31, previous best: 0.445
#
#  -------------
#
# Time for 1930 iterations: 1.0963109334309895 mins
# Train Loss: 0.5840750336647034
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.36
# Current best: 0.36, previous best: 0.445
#
#  -------------
#
# Time for 1940 iterations: 1.1023029764493306 mins
# Train Loss: 0.38182970881462097
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.445
# Current best: 0.445, previous best: 0.445
#
#  -------------
#
# Time for 1950 iterations: 1.1080636660257974 mins
# Train Loss: 0.3188419044017792
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1960 iterations: 1.1147773583730063 mins
# Train Loss: 0.3632259964942932
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.375
# Current best: 0.375, previous best: 0.445
#
#  -------------
#
# Time for 1970 iterations: 1.1211901783943177 mins
# Train Loss: 0.3389969766139984
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.365
# Current best: 0.365, previous best: 0.445
#
#  -------------
#
# Time for 1980 iterations: 1.1274540265401205 mins
# Train Loss: 0.3728361129760742
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.4
# Current best: 0.4, previous best: 0.445
#
#  -------------
#
# Time for 1990 iterations: 1.1338982741038004 mins
# Train Loss: 0.4655398428440094
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.35
# Current best: 0.35, previous best: 0.445
#
#  -------------
#
# Time for 2000 iterations: 1.1403276006380716 mins
# Train Loss: 0.19069893658161163
# Use 8 way one-shot learning on 200 test sets.
# Accuracy is 0.42
# Current best: 0.42, previous best: 0.445

# %%
plt.plot(train_result['iter_num'], train_result['loss'], marker='o')

# %%
from sklearn.linear_model import LinearRegression

model_lr = LinearRegression().fit(np.array(train_result['iter_num']).reshape(-1, 1), \
                                  np.array(train_result['accuracy']).reshape(-1, 1))

lr_y = model_lr.coef_ * np.array(train_result['iter_num']).reshape(-1, 1) +  model_lr.intercept_
plt.plot(train_result['iter_num'], train_result['accuracy'], marker='o')
plt.plot(train_result['iter_num'], lr_y)

# %%
np.mean(train_result['accuracy'])
# Out:
# 0.35590000000000005

# %%
test_result = {
    'N_way':[],
    'accuracy':[],
}
n_iter = 1
N_ways = [i for i in range(1, 9)] # how many classes for testing one-shot tasks
n_val = 2000 # how many one-shot tasks to validate on
# best = -1


for i in range(1, n_iter+1):
    for N_way in N_ways:
        print("\n ------------- \n")
#         print("Time for {0} iterations: {1} mins".format(i, (time.time()-t_start)/60.0))
#         print("Train Loss: {0}".format(loss)) 
        test_acc = test(model, test_dict, categories, N_way, n_val)
        print("Accuracy is ".format(test_acc))
        test_result['N_way'].append(N_way)
        test_result['accuracy'].append(test_acc)

plt.plot(test_result['N_way'], test_result['accuracy'], marker='o')
np.mean(test_result['accuracy'])
# Out:
#  -------------
#
# Use 1 way one-shot learning on 2000 test sets.
# Accuracy is 1.0
# Accuracy is
#
#  -------------
#
# Use 2 way one-shot learning on 2000 test sets.
# Accuracy is 0.7705
# Accuracy is
#
#  -------------
#
# Use 3 way one-shot learning on 2000 test sets.
# Accuracy is 0.646
# Accuracy is
#
#  -------------
#
# Use 4 way one-shot learning on 2000 test sets.
# Accuracy is 0.5525
# Accuracy is
#
#  -------------
#
# Use 5 way one-shot learning on 2000 test sets.
# Accuracy is 0.4765
# Accuracy is
#
#  -------------
#
# Use 6 way one-shot learning on 2000 test sets.
# Accuracy is 0.4165
# Accuracy is
#
#  -------------
#
# Use 7 way one-shot learning on 2000 test sets.
# Accuracy is 0.3995
# Accuracy is
#
#  -------------
#
# Use 8 way one-shot learning on 2000 test sets.
# Accuracy is 0.3575
# Accuracy is
# 0.577375

# %%
test_result['accuracy']
# Out:
# [1.0, 0.7705, 0.646, 0.5525, 0.4765, 0.4165, 0.3995, 0.3575]

# %% [markdown]
# ### Baseline model based on Nearest Neighbors using Euclidean distance (L2 distance)

# %%
def nearest_neighbour_correct(pairs,targets):
    """returns 1 if nearest neighbour gets the correct answer for a one-shot task
        given by (pairs, targets)"""
    L2_distances = np.zeros_like(targets)
    for i in range(len(targets)):
        L2_distances[i] = np.sum(np.sqrt(pairs[0][i]**2 - pairs[1][i]**2))
    if np.argmin(L2_distances) == np.argmax(targets):
        return 1
    return 0

# %%
def test_nn_accuracy(N_ways,n_trials):
    """Returns accuracy of NN approach """
    print("Evaluating nearest neighbour on {} unique {} way one-shot learning tasks ...".format(n_trials,N_ways))

    n_right = 0
    
    for i in range(n_trials):
        test_image_copies, support_set, label = get_batch_test(test_dict, test_categories, N_ways)
        correct = nearest_neighbour_correct([test_image_copies, support_set], label)
        n_right += correct
    return 1.0 * n_right / n_trials

# %%
ways = np.arange(1,21,1)
resume =  False
trials = 200

# %%
val_accs, train_accs,nn_accs = [], [], []
for N in ways:    
#     val_accs.append(test_oneshot(model, N, trials, "val", verbose=True))
#     train_accs.append(test_oneshot(model, N, trials, "train", verbose=True))
    nn_acc = test_nn_accuracy(N, trials)
    nn_accs.append(nn_acc)
    print ("NN Accuracy = ", nn_acc)
    print("---------------------------------------------------------------------------------------------------------------")

# %%
fig, ax = plt.subplots(figsize=(20, 10))
ax.plot(N_ways, test_result['accuracy'], "r", label="Siamese Network (test set)")
ax.plot(N_ways, test_result_train['accuracy'], "y", label="Siamese Network (train set)")
plt.plot(N_ways, nn_accs, label="Nearest neighbour (test set)")
plt.xticks(N_ways, fontsize = 22) 
plt.yticks(fontsize = 22)
ax.plot(N_ways, 1.0/ways, "g", label="Random guessing")
plt.xlabel("N-way Classification", fontsize = 22)
plt.ylabel("Accuracy", fontsize = 22)
plt.title("Siamese Network on Caltech 101", fontsize =22)
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])
ax.legend(fontsize = 22)
# inputs,targets = make_oneshot_task(20, "val", 'Oriya')
plt.show()

# plot_oneshot_task(inputs)
